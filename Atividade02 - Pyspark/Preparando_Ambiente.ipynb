# %% [markdown]
# <h1>Criação do catálogo para organizar </h1>

# %%
# %sql

DROP CATALOG IF EXISTS medalhao CASCADE;
CREATE CATALOG IF NOT EXISTS medalhao

# %% [markdown]
# <h1>Criação de volume</h1>

# %%
# %sql
USE CATALOG medalhao;
USE SCHEMA default; 
CREATE VOLUME IF NOT EXISTS landing
